# %% [markdown]
# # COURSE: A deep understanding of deep learning
# ## SECTION: Math prerequisites
# ### LECTURE: Softmax
# #### TEACHER: Mike X Cohen, sincxpress.com
# ##### COURSE URL: udemy.com/course/deeplearning_x/?couponCode=202401

# %%
# import libraries
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
# compute softmax "manually" in numpy

# the list of numbers
z = [1,2,3]

# compute the softmax result
den = np.exp(z)
num = np.sum( np.exp(z) )
sigma = den / num

print(sigma)
print(np.sum(sigma))
# Out:
# [0.09003057 0.24472847 0.66524096]
# 1.0

# %%
# repeat with some random integers
z = np.random.randint(low=-5,high=15,size=25)
print(z)

# compute the softmax result
num = np.exp(z)
den = np.sum( num )
sigma = num / den

# compare
plt.plot(z,sigma,'ko')
plt.xlabel('Original number (z)')
plt.ylabel('Softmaxified $\sigma$') #LaTex syntax
# plt.yscale('log') #scale the y axis in log
plt.title('$\sum\sigma$ = %g' %np.sum(sigma))
plt.show()
# Out:
# [ 8 -3 10 14 13  2 -5  8 14  9 -1 13  2 -1  1 -3  6  6  3 11  7  6 13  0
#   5]
# <>:13: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# <>:13: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/3k/vsl4hddn56x_g6r3lg43yr8r0000gn/T/ipykernel_3132/2612044632.py:13: SyntaxWarning: invalid escape sequence '\s'
#   plt.ylabel('Softmaxified $\sigma$') #LaTex syntax
# /var/folders/3k/vsl4hddn56x_g6r3lg43yr8r0000gn/T/ipykernel_3132/2612044632.py:15: SyntaxWarning: invalid escape sequence '\s'
#   plt.title('$\sum\sigma$ = %g' %np.sum(sigma))

# %% [markdown]
# # Using pytorch

# %%
# slightly more involved using torch.nn

# create an instance of the softmax activation class
softfun = nn.Softmax(dim=0)

# then apply the data to that function
sigmaT = softfun( torch.Tensor(z) )

# now we get the results
print("Input:", torch.Tensor(z))
print("Output:", sigmaT)
# Out:
# Input: tensor([ 8., -3., 10., 14., 13.,  2., -5.,  8., 14.,  9., -1., 13.,  2., -1.,
#          1., -3.,  6.,  6.,  3., 11.,  7.,  6., 13.,  0.,  5.])
# [7.78133311e-04 1.29961497e-08 5.74967068e-03 3.13921383e-01
#  1.15485223e-01 1.92879964e-06 1.75883760e-09 7.78133311e-04
#  3.13921383e-01 2.11518564e-03 9.60292794e-08 1.15485223e-01
#  1.92879964e-06 9.60292794e-08 7.09565733e-07 1.29961497e-08
#  1.05308892e-04 1.05308892e-04 5.24302100e-06 1.56292253e-02
#  2.86259247e-04 1.05308892e-04 1.15485223e-01 2.61034645e-07
#  3.87409763e-05]
# Output: tensor([7.7813e-04, 1.2996e-08, 5.7497e-03, 3.1392e-01, 1.1549e-01, 1.9288e-06,
#         1.7588e-09, 7.7813e-04, 3.1392e-01, 2.1152e-03, 9.6029e-08, 1.1549e-01,
#         1.9288e-06, 9.6029e-08, 7.0957e-07, 1.2996e-08, 1.0531e-04, 1.0531e-04,
#         5.2430e-06, 1.5629e-02, 2.8626e-04, 1.0531e-04, 1.1549e-01, 2.6103e-07,
#         3.8741e-05])

# %%
# show that they are the same
plt.plot(sigma,sigmaT,'ko')
plt.xlabel('"Manual" softmax')
plt.ylabel('Pytorch nn.Softmax')
plt.title(f'The two methods correlate at r={np.corrcoef(sigma,sigmaT)[0,1]}')
plt.show()
